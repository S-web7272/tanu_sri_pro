# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("data/Canada.xlsx",sheet_name="Canada by Citizenship")
df
# Out:
#               Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                    NaN         NaN        NaN        NaN        NaN
# 1                    NaN         NaN        NaN        NaN        NaN
# 2                    NaN         NaN        NaN        NaN        NaN
# 3         United Nations         NaN        NaN        NaN        NaN
# 4    Population Division         NaN        NaN        NaN        NaN
# ..                   ...         ...        ...        ...        ...
# 212           Immigrants  Foreigners      Yemen        935       Asia
# 213           Immigrants  Foreigners     Zambia        903     Africa
# 214           Immigrants  Foreigners   Zimbabwe        903     Africa
# 215           Immigrants  Foreigners    Unknown        999      World
# 216           Immigrants        Both      Total        999      World
#
#     Unnamed: 5      Unnamed: 6 Unnamed: 7          Unnamed: 8  Unnamed: 9  \
# ...

# %%
df = pd.read_excel("data/Canada.xlsx",
                   sheet_name="Canada by Citizenship",skiprows=20)
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 195  Immigrants  Foreigners         Unknown   999    World   999
# 196  Immigrants        Both           Total   999    World   999
#
#              RegName  DEV             DevName    1980  ...    2012    2013  \
# 0      Southern Asia  902  Developing regions      16  ...    2635    2004
# ...

# %%
df = pd.read_excel("data/Canada.xlsx",
                   sheet_name="Canada by Citizenship",skiprows=20,
                  nrows=195)
df
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# ..          ...         ...             ...   ...      ...   ...
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
#
#                 RegName  DEV             DevName  1980  ...  2012  2013  \
# 0         Southern Asia  902  Developing regions    16  ...  2635  2004
# ...

# %%
df.columns
# Out:
# Index([       'Type',    'Coverage',      'OdName',        'AREA',
#           'AreaName',         'REG',     'RegName',         'DEV',
#            'DevName',          1980,          1981,          1982,
#                 1983,          1984,          1985,          1986,
#                 1987,          1988,          1989,          1990,
#                 1991,          1992,          1993,          1994,
#                 1995,          1996,          1997,          1998,
#                 1999,          2000,          2001,          2002,
#                 2003,          2004,          2005,          2006,
#                 2007,          2008,          2009,          2010,
#                 2011,          2012,          2013, 'Unnamed: 43',
#        'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47',
#        'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50'],
#       dtype='object')

# %%
cols_to_drop = ['Unnamed: 43','Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47','Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50']
df.drop(labels=cols_to_drop,axis=1,inplace=True)

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %% [markdown]
# check columns for data uniqueness

# %%
df['Type'].value_counts()
# all the values  repeat thus not usefull
# Out:
# Immigrants    195
# Name: Type, dtype: int64

# %%
df['Coverage'].value_counts() # all the values  repeat except 1- thus not usefull
# Out:
# Foreigners    194
# Citizens        1
# Name: Coverage, dtype: int64

# %%
df['DevName'].value_counts()
# Out:
# Developing regions    147
# Developed regions      48
# Name: DevName, dtype: int64

# %%
df['OdName'].value_counts()
# Out:
# Mali              1
# Oman              1
# Mauritius         1
# American Samoa    1
# Austria           1
#                  ..
# Senegal           1
# Lebanon           1
# New Zealand       1
# Angola            1
# Germany           1
# Name: OdName, Length: 195, dtype: int64

# %% [markdown]
# .chenge the columns name,

# %% [markdown]
# .make country column as index and

# %% [markdown]
# .remove the columns that are not required

# %%
df.columns
# Out:
# Index([    'Type', 'Coverage',   'OdName',     'AREA', 'AreaName',      'REG',
#         'RegName',      'DEV',  'DevName',       1980,       1981,       1982,
#              1983,       1984,       1985,       1986,       1987,       1988,
#              1989,       1990,       1991,       1992,       1993,       1994,
#              1995,       1996,       1997,       1998,       1999,       2000,
#              2001,       2002,       2003,       2004,       2005,       2006,
#              2007,       2008,       2009,       2010,       2011,       2012,
#              2013],
#       dtype='object')

# %%
df.rename({'OdName':'Country',
           'AreaName':'Continent',
           'RegName':'Region',
           'DevName':'Status'},axis=1, inplace=True)
df.head()
# Out:
#          Type    Coverage         Country  AREA Continent   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 1  Immigrants  Foreigners         Albania   908    Europe   925
# 2  Immigrants  Foreigners         Algeria   903    Africa   912
# 3  Immigrants  Foreigners  American Samoa   909   Oceania   957
# 4  Immigrants  Foreigners         Andorra   908    Europe   925
#
#             Region  DEV              Status  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.set_index('Country',inplace=True)

# %%
df.head()[2013].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Country'>

# %%
cols = ['Type','Coverage','AREA','REG','DEV']
df.drop(cols,axis=1,inplace=True)
df.head()
# Out:
#                Continent           Region              Status  1980  1981  \
# Country
# Afghanistan         Asia    Southern Asia  Developing regions    16    39
# Albania           Europe  Southern Europe   Developed regions     1     0
# Algeria           Africa  Northern Africa  Developing regions    80    67
# American Samoa   Oceania        Polynesia  Developing regions     0     1
# Andorra           Europe  Southern Europe   Developed regions     0     0
#
#                 1982  1983  1984  1985  1986  ...  2004  2005  2006  2007  \
# Country                                       ...
# Afghanistan       39    47    71   340   496  ...  2978  3436  3009  2652
# Albania            0     0     0     0     1  ...  1450  1223   856   702
# Algeria           71    69    63    44    69  ...  3616  3626  4807  3623
# American Samoa     0     0     0     0     0  ...     0     0     1     0
# Andorra            0     0     0     0     2  ...     0     0     1     1
#
# ...

# %%
df.groupby('Continent')[2013].sum().plot(kind='pie',figsize=(8,8),title='continent wise immigration in 2013',autopct='%.3f%%')
plt.show()

# %%
df.groupby('Continent')[1985,2013].sum().plot(kind='pie',subplots=True,figsize=(16,8),title='continent wise immigration in 1985,2013',autopct='%.3f%%')
plt.show()
# Out:
# <ipython-input-18-9230c279648b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Continent')[1985,2013].sum().plot(kind='pie',subplots=True,figsize=(16,8),title='continent wise immigration in 1985,2013',autopct='%.3f%%')

# %%
df.groupby('Continent')[1985].sum().plot(kind='pie',figsize=(8,8),title='continent wise immigration in 1985',autopct='%.3f%%')
plt.show()

# %%
years = list(range(1980,2014))
df_france = df.loc[['France'],years]

# %%
df_france.T.describe()
# Out:
# Country       France
# count      34.000000
# mean     3208.558824
# std      1295.448026
# min      1169.000000
# 25%      2187.500000
# 50%      3337.500000
# 75%      4060.500000
# max      6280.000000

# %%
df_france.T.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df_fg = df.loc[['France','Germany'],years].T
df_fg
# Out:
# Country  France  Germany
# 1980       1729     1626
# 1981       2027     1977
# 1982       2219     3062
# 1983       1490     2376
# 1984       1169     1610
# 1985       1177     1441
# 1986       1298     1233
# 1987       1658     1704
# 1988       2038     1482
# 1989       2332     1706
# 1990       2177     1273
# 1991       2911     1273
# 1992       3487     1181
# 1993       3709     1488
# 1994       2759     1255
# 1995       3332     1553
# 1996       2623     1686
# 1997       2473     1397
# 1998       3214     1363
# 1999       3343     1717
# 2000       3765     1703
# 2001       3806     1456
# 2002       3463     1375
# 2003       3568     1865
# 2004       4391     2020
# 2005       4429     2226
# 2006       4002     2767
# 2007       4290     2449
# 2008       4532     3833
# 2009       5051     3887
# 2010       4646     2956
# 2011       4080     2053
# 2012       6280     1702
# 2013       5623     1217

# %%
df_fg.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.columns.tolist()
# Out:
# ['Type',
#  'Coverage',
#  'AREA',
#  'Continent',
#  'REG',
#  'Region',
#  'DEV',
#  'Status',
#  1980,
#  1981,
#  1982,
#  1983,
#  1984,
#  1985,
#  1986,
#  1987,
#  1988,
#  1989,
#  1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013]

# %%
df['Total'] = df[years].sum(axis=1)

# %%
df
# Out:
#                       Type    Coverage  AREA Continent   REG  \
# Country
# Afghanistan     Immigrants  Foreigners   935      Asia  5501
# Albania         Immigrants  Foreigners   908    Europe   925
# Algeria         Immigrants  Foreigners   903    Africa   912
# American Samoa  Immigrants  Foreigners   909   Oceania   957
# Andorra         Immigrants  Foreigners   908    Europe   925
# ...                    ...         ...   ...       ...   ...
# Viet Nam        Immigrants  Foreigners   935      Asia   920
# Western Sahara  Immigrants  Foreigners   903    Africa   912
# Yemen           Immigrants  Foreigners   935      Asia   922
# Zambia          Immigrants  Foreigners   903    Africa   910
# Zimbabwe        Immigrants  Foreigners   903    Africa   910
#
#                             Region  DEV              Status  1980  1981  ...  \
# Country                                                                  ...
# ...

# %%
df
# Out:
#                       Type    Coverage  AREA Continent   REG  \
# Country
# Afghanistan     Immigrants  Foreigners   935      Asia  5501
# Albania         Immigrants  Foreigners   908    Europe   925
# Algeria         Immigrants  Foreigners   903    Africa   912
# American Samoa  Immigrants  Foreigners   909   Oceania   957
# Andorra         Immigrants  Foreigners   908    Europe   925
# ...                    ...         ...   ...       ...   ...
# Viet Nam        Immigrants  Foreigners   935      Asia   920
# Western Sahara  Immigrants  Foreigners   903    Africa   912
# Yemen           Immigrants  Foreigners   935      Asia   922
# Zambia          Immigrants  Foreigners   903    Africa   910
# Zimbabwe        Immigrants  Foreigners   903    Africa   910
#
#                             Region  DEV              Status  1980  1981  ...  \
# Country                                                                  ...
# ...

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.columns.tolist()
# Out:
# ['survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'who',
#  'adult_male',
#  'deck',
#  'embark_town',
#  'alive',
#  'alone']

# %%
titanic.plot(kind='scatter',x='age',y='fare',s=100,alpha=.54, edgecolor='yellow')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
df.sort_values(by='Total',inplace=True,ascending=False)

# %%
df
# Out:
#                                                           Type    Coverage  \
# Country
# India                                               Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# Pakistan                                            Immigrants  Foreigners
# ...                                                        ...         ...
# San Marino                                          Immigrants  Foreigners
# New Caledonia                                       Immigrants  Foreigners
# Marshall Islands                                    Immigrants  Foreigners
# Western Sahara                                      Immigrants  Foreigners
# Palau                                               Immigrants  Foreigners
#
# ...

# %%
df.head()[years].T.plot(kind='area',stacked=False,alpha=.3,figsize=(20,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# plot

# %% [markdown]
# ** bar for value wise comparison

# %% [markdown]
# **pie for percent based comparison

# %% [markdown]
# **area for line for time series comparision

# %% [markdown]
# **scatter for comparin 2 or 3 items in data

# %% [markdown]
# **boxplot for understanding the statistic of data

# %% [markdown]
# **histogram for understanding the frequency of distrubution

# %%
df.head()[years].T.plot(kind='hist',alpha=.3,figsize=(5,20),subplots=True)
plt.show()

# %%
df.plot.hexbin?
# Out:
# Signature:
# df.plot.hexbin(
#     x,
#     y,
#     C=None,
#     reduce_C_function=None,
#     gridsize=None,
#     **kwargs,
# )
# Docstring:
# Generate a hexagonal binning plot.
#
# Generate a hexagonal binning plot of `x` versus `y`. If `C` is `None`
# (the default), this is a histogram of the number of occurrences
# of the observations at ``(x[i], y[i])``.
#
# If `C` is specified, specifies values at given coordinates
# ``(x[i], y[i])``. These values are accumulated for each hexagonal
# bin and then reduced according to `reduce_C_function`,
# having as default the NumPy's mean function (:meth:`numpy.mean`).
# (If `C` is specified, it must also be a 1-D sequence
# of the same length as `x` and `y`, or a column label.)
#
# Parameters
# ----------
# x : int or str
#     The column label or position for x points.
# y : int or str
#     The column label or position for y points.
# C : int or str, optional
#     The column label or position for the value of `(x, y)` point.
# ...

# %%
titanic.plot(kind='scatter',x='age',y='fare',figsize=(10,10),marker='*',s=1000,color='green')
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>
